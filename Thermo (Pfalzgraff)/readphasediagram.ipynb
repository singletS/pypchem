# %%
from numpy import *
from matplotlib.pyplot import *
# %matplotlib notebook

# %%
evap = loadtxt('evaporation_line.dat')
T_evap = evap[:,0]; P_evap = evap[:,1]
melt = loadtxt('melting_line.dat')
T_melt = melt[:,0]; P_melt = melt[:,1]
subl = loadtxt('sublimation_line.dat')
T_subl = subl[:,0]; P_subl = subl[:,1]

# %%
figure()
semilogy(T_evap,P_evap,'o')
semilogy(T_melt,P_melt,'o')
semilogy(T_subl,P_subl,'o')
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">
